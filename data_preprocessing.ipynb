# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

test_data = pd.read_csv(Path("Resources/test_Y3wMUE5_7gLdaTN.csv"))
train_data = pd.read_csv(Path("Resources/train_u6lujuX_CVtuZ9i.csv"))

# %%
test_data.head()
#test_data.isnull().sum()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
train_data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Gather Basic Info on Dataset

# %%
train_data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
train_data.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
train_data.columns.tolist()
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'Loan_Status']

# %%
# Check for null values in the dataset:
train_data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Are there any null values in the Loan_Status column?
train_data['Loan_Status'].isnull().sum()
# Out:
# 0

# %%
# Check for an imbalanced dataset using value counts of Loan_Status column
# NOTE: consider plotting this data to visualize
train_data['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
# Check column value counts for possible use of GetDummies for preprocessing
# train_data['Loan_Amount_Term'].value_counts() (MAYBE)
# train_data['LoanAmount'].value_counts() (NO)
# train_data['Credit_History'].value_counts() (alredy numerical)
# train_data['Dependents'].value_counts() (MAYBE)
# train_data['Property_Area'].value_counts() (YES)
# train_data['Total_Income'].value_counts()

# %% [markdown]
# The Dataset is Imbalanced. We will need to balance the dataset.
#
# DONE -- Loan_ID: DROP COLUMN
#
# DONE -- Gender: encode numerically by defining encoding function
# - Drop All Null
#
# DONE -- Married: encode numerically by defining encoding function
# - Drop All Null
#
# Dependents: Get Dummies or OneHotEncoding?
# - Look into logic of encoding all null values based on Marriage value
# - one hot encode the values as text since they represent distinct groups?
# - can take the mean or median of the dependants column where Married == 'Yes' (or 1)
#
# DONE -- Education: encode numerically by defining encoding function
# - no null values exist
#
# DONE -- Self_Employed: encode numerically by defining encoding function
# - Change all null to not self employed
#
# DONE -- ApplicantIncome: already numerical (confirm all numerical values)
# - combine with CoapplicantIncome
#
# DONE -- CoapplicantIncome: already numerical (confirm all numerical values)
# - combine with ApplicatIncome
#
# DONE -- LoanAmount: already numerical (confirm all numerical values)
# - K Nearest Neighbor?
#
# Loan_Amount_Term: encode numerically by defining encoding function
# - Change all null to 360. Prediction would rsult in the same
#
# DONE -- Credit_History: already numerical
# - use K Nearest Neighbors where loan status = No to predict replacements for null values and apply.
#
# Property_Area: Get Dummies.
#
# Loan_Status: NOTHING TO CHANGE

# %% [markdown]
# # Data Transformation Section

# %%
train_data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
preprocessing_df = train_data.copy()
preprocessing_df['Total_Income'] = preprocessing_df['ApplicantIncome'] + preprocessing_df['CoapplicantIncome']
preprocessing_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_Income
# 0             1.0         Urban           Y        5849.0
# ...

# %%
columns_to_drop = ['Loan_ID', 'ApplicantIncome', 'CoapplicantIncome']
preprocessing_df.drop(columns=columns_to_drop, inplace=True)
preprocessing_df = preprocessing_df[['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Total_Income', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status']]
preprocessing_df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Total_Income  \
# 0   Male      No          0      Graduate            No        5849.0
# 1   Male     Yes          1      Graduate            No        6091.0
# 2   Male     Yes          0      Graduate           Yes        3000.0
# 3   Male     Yes          0  Not Graduate            No        4941.0
# 4   Male      No          0      Graduate            No        6000.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0         NaN             360.0             1.0         Urban           Y
# 1       128.0             360.0             1.0         Rural           N
# 2        66.0             360.0             1.0         Urban           Y
# 3       120.0             360.0             1.0         Urban           Y
# 4       141.0             360.0             1.0         Urban           Y

# %%
# change the dependants values from str to int
preprocessing_df.loc[(preprocessing_df['Dependents'] == '0'), 'Dependents'] = 0
preprocessing_df.loc[(preprocessing_df['Dependents'] == '1'), 'Dependents'] = 1
preprocessing_df.loc[(preprocessing_df['Dependents'] == '2'), 'Dependents'] = 2
preprocessing_df.loc[(preprocessing_df['Dependents'] == '3+'), 'Dependents'] = 3

# %%
# view the total null values in df
preprocessing_df.isnull().sum()
# Out:
# Gender              13
# Married              3
# Dependents          15
# Education            0
# Self_Employed       32
# Total_Income         0
# LoanAmount          22
# Loan_Amount_Term    14
# Credit_History      50
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# # Handling Null Values

# %%
# DEPENDENTS: Change null values for rows where Married == Yes to 1 and Married == No to 0
preprocessing_df.loc[(preprocessing_df['Dependents'].isnull()) & (preprocessing_df['Married'] == 'Yes'), 'Dependents'] = 1
preprocessing_df.loc[(preprocessing_df['Dependents'].isnull()) & (preprocessing_df['Married'] == 'No'), 'Dependents'] = 0

# %%
preprocessing_df["Dependents"].isnull().sum()
# Out:
# 3

# %%
# GENDER: Remove all rows with null values
gender_drop = preprocessing_df[preprocessing_df['Gender'].isnull()]
preprocessing_df.drop(index=gender_drop.index, inplace=True)
preprocessing_df.reset_index(drop=True, inplace=True)
preprocessing_df['Gender'].isnull().sum()
# Out:
# 0

# %%
# MARRIED: Remove all rows with null values
marriage_drop = preprocessing_df[preprocessing_df['Married'].isnull()]
preprocessing_df.drop(index=marriage_drop.index, inplace=True)
preprocessing_df.reset_index(drop=True, inplace=True)
preprocessing_df['Married'].isnull().sum()
# Out:
# 0

# %%
# CREDIT_HISTORY & LOANAMOUNT 
# Use K-Nearest Neighbors to fill in null values for Credit_History and LoanAmount columns
from sklearn.impute import KNNImputer
columns_for_imputation = ['Credit_History', 'LoanAmount']
# Create a KNNImputer instance
imputer = KNNImputer(n_neighbors=5)

# Perform imputation on the selected columns
# train_df_imputed = train_df.copy()  # Make a copy of the original DataFrame to preserve it
preprocessing_df[columns_for_imputation] = imputer.fit_transform(preprocessing_df[columns_for_imputation])

# Check for any remaining missing values after imputation
preprocessing_df.isnull().sum()
preprocessing_df['Credit_History'] = preprocessing_df['Credit_History'].round()

# Review the DataFrame 
preprocessing_df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Total_Income  \
# 0   Male      No          0      Graduate            No        5849.0
# 1   Male     Yes          1      Graduate            No        6091.0
# 2   Male     Yes          0      Graduate           Yes        3000.0
# 3   Male     Yes          0  Not Graduate            No        4941.0
# 4   Male      No          0      Graduate            No        6000.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0       121.0             360.0             1.0         Urban           Y
# 1       128.0             360.0             1.0         Rural           N
# 2        66.0             360.0             1.0         Urban           Y
# 3       120.0             360.0             1.0         Urban           Y
# 4       141.0             360.0             1.0         Urban           Y

# %%
# Convert all null values to 360 as the mean value for Loan_Amount-Term
preprocessing_df.loc[(preprocessing_df['Loan_Amount_Term'].isnull()), 'Loan_Amount_Term'] = 360
preprocessing_df['Loan_Amount_Term'].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    514
# 180.0     43
# 480.0     14
# 300.0     12
# 84.0       4
# 120.0      3
# 240.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
# Ensure null values have been removed.
# Note: Self_Employed nulls will be handled with encoding function
preprocessing_df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed       32
# Total_Income         0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# # Encoding the Data as Numerical

# %% [markdown]
# ## Gender

# %%
# Encoding Gender Column numerically by setting Female = 1 and Male = 0
def encode_gender(gender):
    if gender == "Female":
        return 1
    else:
        return 0

# Call the encode_gender function on the gender column
preprocessing_df["Gender"] = preprocessing_df["Gender"].apply(encode_gender)

# Review the DataFrame 
preprocessing_df.head()
# Out:
#    Gender Married Dependents     Education Self_Employed  Total_Income  \
# 0       0      No          0      Graduate            No        5849.0
# 1       0     Yes          1      Graduate            No        6091.0
# 2       0     Yes          0      Graduate           Yes        3000.0
# 3       0     Yes          0  Not Graduate            No        4941.0
# 4       0      No          0      Graduate            No        6000.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0       121.0             360.0             1.0         Urban           Y
# 1       128.0             360.0             1.0         Rural           N
# 2        66.0             360.0             1.0         Urban           Y
# 3       120.0             360.0             1.0         Urban           Y
# 4       141.0             360.0             1.0         Urban           Y

# %% [markdown]
# ## Marriage

# %%
# Encoding Marriage Column numerically by setting yes = 1 and no = 0
def encode_marriage(marriage):
    if marriage == "Yes":
        return 1
    else:
        return 0

# Call the encode_marriage function on the marriage column
preprocessing_df["Married"] = preprocessing_df["Married"].apply(encode_marriage)

# Review the DataFrame 
preprocessing_df.head()
# Out:
#    Gender  Married Dependents     Education Self_Employed  Total_Income  \
# 0       0        0          0      Graduate            No        5849.0
# 1       0        1          1      Graduate            No        6091.0
# 2       0        1          0      Graduate           Yes        3000.0
# 3       0        1          0  Not Graduate            No        4941.0
# 4       0        0          0      Graduate            No        6000.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0       121.0             360.0             1.0         Urban           Y
# 1       128.0             360.0             1.0         Rural           N
# 2        66.0             360.0             1.0         Urban           Y
# 3       120.0             360.0             1.0         Urban           Y
# 4       141.0             360.0             1.0         Urban           Y

# %% [markdown]
# ## Education

# %%
# No null values exist for Education
# Encoding Education Column by setting yes as 1 and no as 0
def encode_edu(edu):
    if edu == "Graduate":
        return 1
    else:
        return 0

# Call the encode_edu function on the Education column
preprocessing_df["Education"] = preprocessing_df["Education"].apply(encode_edu)

# Review the DataFrame 
preprocessing_df.head()
# Out:
#    Gender  Married Dependents  Education Self_Employed  Total_Income  \
# 0       0        0          0          1            No        5849.0
# 1       0        1          1          1            No        6091.0
# 2       0        1          0          1           Yes        3000.0
# 3       0        1          0          0            No        4941.0
# 4       0        0          0          1            No        6000.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0       121.0             360.0             1.0         Urban           Y
# 1       128.0             360.0             1.0         Rural           N
# 2        66.0             360.0             1.0         Urban           Y
# 3       120.0             360.0             1.0         Urban           Y
# 4       141.0             360.0             1.0         Urban           Y

# %% [markdown]
# ## Self_Employed

# %%
# Encoding Self_Employed Column by setting yes as 1 and no as 0 
# Null values will also be encoded as 0 using this method
def encode_employ(employment):
    if employment == "Yes":
        return 1
    else:
        return 0

# Call the encode_edu function on the Education column
preprocessing_df["Self_Employed"] = preprocessing_df["Self_Employed"].apply(encode_employ)

# Review the DataFrame 
preprocessing_df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  Total_Income  \
# 0       0        0          0          1              0        5849.0
# 1       0        1          1          1              0        6091.0
# 2       0        1          0          1              1        3000.0
# 3       0        1          0          0              0        4941.0
# 4       0        0          0          1              0        6000.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0       121.0             360.0             1.0         Urban           Y
# 1       128.0             360.0             1.0         Rural           N
# 2        66.0             360.0             1.0         Urban           Y
# 3       120.0             360.0             1.0         Urban           Y
# 4       141.0             360.0             1.0         Urban           Y

# %%
# Check for null values
preprocessing_df['Self_Employed'].isnull().sum()
# Out:
# 0

# %%
# Encoding Target 'Loan_Status' Column by setting yes as 1 and no as 0 
def encode_(employment):
    if employment == "Yes":
        return 1
    else:
        return 0

# Call the encode_edu function on the Education column
preprocessing_df["Self_Employed"] = preprocessing_df["Self_Employed"].apply(encode_employ)

# Review the DataFrame 
preprocessing_df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  Total_Income  \
# 0       0        0          0          1              0        5849.0
# 1       0        1          1          1              0        6091.0
# 2       0        1          0          1              0        3000.0
# 3       0        1          0          0              0        4941.0
# 4       0        0          0          1              0        6000.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0       121.0             360.0             1.0         Urban           Y
# 1       128.0             360.0             1.0         Rural           N
# 2        66.0             360.0             1.0         Urban           Y
# 3       120.0             360.0             1.0         Urban           Y
# 4       141.0             360.0             1.0         Urban           Y

# %%
# Confirm null values have been handled
preprocessing_df['Self_Employed'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Dependents & Property_Area

# %%
df_dummies = pd.get_dummies(preprocessing_df[['Dependents', 'Property_Area']], dtype='int')
df_dummies
# Out:
#      Dependents_0  Dependents_1  Dependents_2  Dependents_3  \
# 0               1             0             0             0
# 1               0             1             0             0
# 2               1             0             0             0
# 3               1             0             0             0
# 4               1             0             0             0
# ..            ...           ...           ...           ...
# 593             1             0             0             0
# 594             0             0             0             1
# 595             0             1             0             0
# 596             0             0             1             0
# 597             1             0             0             0
#
#      Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban
# 0                      0                        0                    1
# 1                      1                        0                    0
# ...

# %%
preprocessing_df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  Total_Income  \
# 0       0        0          0          1              0        5849.0
# 1       0        1          1          1              0        6091.0
# 2       0        1          0          1              0        3000.0
# 3       0        1          0          0              0        4941.0
# 4       0        0          0          1              0        6000.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History Property_Area Loan_Status
# 0       121.0             360.0             1.0         Urban           Y
# 1       128.0             360.0             1.0         Rural           N
# 2        66.0             360.0             1.0         Urban           Y
# 3       120.0             360.0             1.0         Urban           Y
# 4       141.0             360.0             1.0         Urban           Y

# %%
preprocessed_final_df = pd.concat([preprocessing_df, df_dummies], axis=1)
preprocessed_final_df.drop(columns=['Dependents', 'Property_Area'], inplace=True)
preprocessed_final_df
# Out:
#      Gender  Married  Education  Self_Employed  Total_Income  LoanAmount  \
# 0         0        0          1              0        5849.0       121.0
# 1         0        1          1              0        6091.0       128.0
# 2         0        1          1              0        3000.0        66.0
# 3         0        1          0              0        4941.0       120.0
# 4         0        0          1              0        6000.0       141.0
# ..      ...      ...        ...            ...           ...         ...
# 593       1        0          1              0        2900.0        71.0
# 594       0        1          1              0        4106.0        40.0
# 595       0        1          1              0        8312.0       253.0
# 596       0        1          1              0        7583.0       187.0
# 597       1        0          1              0        4583.0       133.0
#
#      Loan_Amount_Term  Credit_History Loan_Status  Dependents_0  Dependents_1  \
# ...

# %%
preprocessed_final_df = preprocessed_final_df[['Gender', 'Married', 'Dependents_0', 'Dependents_1', 'Dependents_2', 'Dependents_3', 'Education', 'Self_Employed', 'Total_Income', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Property_Area_Rural', 'Property_Area_Semiurban', 'Property_Area_Urban', 'Loan_Status']]

# Visualize the end resulting df
preprocessed_final_df
# Out:
#      Gender  Married  Dependents_0  Dependents_1  Dependents_2  Dependents_3  \
# 0         0        0             1             0             0             0
# 1         0        1             0             1             0             0
# 2         0        1             1             0             0             0
# 3         0        1             1             0             0             0
# 4         0        0             1             0             0             0
# ..      ...      ...           ...           ...           ...           ...
# 593       1        0             1             0             0             0
# 594       0        1             0             0             0             1
# 595       0        1             0             1             0             0
# 596       0        1             0             0             1             0
# 597       1        0             1             0             0             0
#
# ...

# %%
preprocessed_final_df.to_csv('preprocessed_train_data.csv', index=False)
