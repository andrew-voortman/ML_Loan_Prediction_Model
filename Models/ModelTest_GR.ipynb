# %% [markdown]
# <a href="https://colab.research.google.com/github/andrew-voortman/ML_Loan_Prediction_Model/blob/main/Test_Loan_Prediction_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# %matplotlib inline

# %%
# For creating models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from google.colab import drive
drive.mount('/content/drive')
#train_df = pd.read_csv('/content/drive/My Drive/project4/Resources/train_u6lujuX_CVtuZ9i.csv')
#test_df = pd.read_csv('/content/drive/My Drive/project4/Resources/test_Y3wMUE5_7gLdaTN.csv')
preprocessing_df = pd.read_csv('/content/drive/My Drive/project4/Resources/preprocessed_train_data2.csv')
preprocessing_df.head(10)
# Out:
# Mounted at /content/drive
#    Gender  Married  Dependents  Education  Self_Employed  Total_Income  \
# 0       0        0           0          1              0        5849.0
# 1       0        1           1          1              0        6091.0
# 2       0        1           0          1              1        3000.0
# 3       0        1           0          0              0        4941.0
# 4       0        0           0          1              0        6000.0
# 5       0        1           2          1              1        9613.0
# 6       0        1           0          0              0        3849.0
# 7       0        1           3          1              0        5540.0
# 8       0        1           2          1              0        5532.0
# 9       0        1           1          1              0       23809.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History Loan_Status  \
# 0       121.0             360.0             1.0           Y
# 1       128.0             360.0             1.0           N
# 2        66.0             360.0             1.0           Y
# 3       120.0             360.0             1.0           Y
# 4       141.0             360.0             1.0           Y
# 5       267.0             360.0             1.0           Y
# 6        95.0             360.0             1.0           Y
# 7       158.0             360.0             0.0           N
# 8       168.0             360.0             1.0           Y
# 9       349.0             360.0             1.0           N
#
#    Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban
# 0                    0                        0                    1
# 1                    1                        0                    0
# 2                    0                        0                    1
# 3                    0                        0                    1
# 4                    0                        0                    1
# 5                    0                        0                    1
# 6                    0                        0                    1
# 7                    0                        1                    0
# 8                    0                        0                    1
# 9                    0                        1                    0

# %%
# Encode target variable
def loan_status(loan):
    if loan == "Y":
        return 1
    else:
        return 0

# Call the encode_edu function on the Education column
preprocessing_df["Loan_Status"] = preprocessing_df["Loan_Status"].apply(loan_status)

# Review the DataFrame
preprocessing_df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Total_Income  \
# 0       0        0           0          1              0        5849.0
# 1       0        1           1          1              0        6091.0
# 2       0        1           0          1              1        3000.0
# 3       0        1           0          0              0        4941.0
# 4       0        0           0          1              0        6000.0
#
#    LoanAmount  Loan_Amount_Term  Credit_History  Loan_Status  \
# 0       121.0             360.0             1.0            1
# 1       128.0             360.0             1.0            0
# 2        66.0             360.0             1.0            1
# 3       120.0             360.0             1.0            1
# 4       141.0             360.0             1.0            1
#
#    Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban
# 0                    0                        0                    1
# 1                    1                        0                    0
# 2                    0                        0                    1
# 3                    0                        0                    1
# 4                    0                        0                    1

# %%
# MODIFICATION
# Drop Gender Column
preprocessing_df.drop('Gender', axis=1, inplace=True)
preprocessing_df.head()
# Out:
#    Married  Dependents  Education  Self_Employed  Total_Income  LoanAmount  \
# 0        0           0          1              0        5849.0       121.0
# 1        1           1          1              0        6091.0       128.0
# 2        1           0          1              1        3000.0        66.0
# 3        1           0          0              0        4941.0       120.0
# 4        0           0          1              0        6000.0       141.0
#
#    Loan_Amount_Term  Credit_History  Loan_Status  Property_Area_Rural  \
# 0             360.0             1.0            1                    0
# 1             360.0             1.0            0                    1
# 2             360.0             1.0            1                    0
# 3             360.0             1.0            1                    0
# 4             360.0             1.0            1                    0
#
#    Property_Area_Semiurban  Property_Area_Urban
# 0                        0                    1
# 1                        0                    0
# 2                        0                    1
# 3                        0                    1
# 4                        0                    1

# %%
# Split our preprocessed data into our features and target arrays
X = preprocessing_df.drop("Loan_Status", axis=1)
y = preprocessing_df["Loan_Status"]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len( X_train_scaled[0])
hidden_nodes_layer1=100
hidden_nodes_layer2=5
hidden_nodes_layer3=1

nn = tf.keras.models.Sequential()

# %%
# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_70 (Dense)            (None, 100)               1200
#
#  dense_71 (Dense)            (None, 5)                 505
#
#  dense_72 (Dense)            (None, 1)                 6
#
#  dense_73 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 1713 (6.69 KB)
# Trainable params: 1713 (6.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 2ms/step - loss: 0.6468 - accuracy: 0.6875
# Epoch 2/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5930 - accuracy: 0.6853
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5564 - accuracy: 0.6853
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5330 - accuracy: 0.6853
# Epoch 5/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5187 - accuracy: 0.6853
# Epoch 6/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5115 - accuracy: 0.6853
# Epoch 7/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5059 - accuracy: 0.6853
# Epoch 8/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5027 - accuracy: 0.6853
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4986 - accuracy: 0.7388
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4961 - accuracy: 0.8192
# Epoch 11/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4930 - accuracy: 0.8214
# Epoch 12/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4909 - accuracy: 0.8214
# Epoch 13/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.4882 - accuracy: 0.8192
# Epoch 14/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4853 - accuracy: 0.8214
# Epoch 15/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4838 - accuracy: 0.8237
# Epoch 16/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.4817 - accuracy: 0.8237
# Epoch 17/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4794 - accuracy: 0.8259
# Epoch 18/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4774 - accuracy: 0.8259
# Epoch 19/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4763 - accuracy: 0.8304
# Epoch 20/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4737 - accuracy: 0.8304
# Epoch 21/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4714 - accuracy: 0.8326
# Epoch 22/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4698 - accuracy: 0.8304
# Epoch 23/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4684 - accuracy: 0.8326
# Epoch 24/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4663 - accuracy: 0.8326
# Epoch 25/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4631 - accuracy: 0.8371
# Epoch 26/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4620 - accuracy: 0.8371
# Epoch 27/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4617 - accuracy: 0.8326
# Epoch 28/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4603 - accuracy: 0.8326
# Epoch 29/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4574 - accuracy: 0.8304
# Epoch 30/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4555 - accuracy: 0.8371
# Epoch 31/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4533 - accuracy: 0.8348
# Epoch 32/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4519 - accuracy: 0.8326
# Epoch 33/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4495 - accuracy: 0.8371
# Epoch 34/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4480 - accuracy: 0.8348
# Epoch 35/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4459 - accuracy: 0.8348
# Epoch 36/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4447 - accuracy: 0.8393
# Epoch 37/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4427 - accuracy: 0.8371
# Epoch 38/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4407 - accuracy: 0.8348
# Epoch 39/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4391 - accuracy: 0.8371
# Epoch 40/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4377 - accuracy: 0.8415
# Epoch 41/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4355 - accuracy: 0.8415
# Epoch 42/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4357 - accuracy: 0.8348
# Epoch 43/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4316 - accuracy: 0.8393
# Epoch 44/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4317 - accuracy: 0.8482
# Epoch 45/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4304 - accuracy: 0.8393
# Epoch 46/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4280 - accuracy: 0.8460
# Epoch 47/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4254 - accuracy: 0.8504
# Epoch 48/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4245 - accuracy: 0.8438
# Epoch 49/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4225 - accuracy: 0.8504
# Epoch 50/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4206 - accuracy: 0.8482
# Epoch 51/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4181 - accuracy: 0.8571
# Epoch 52/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4174 - accuracy: 0.8549
# Epoch 53/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4153 - accuracy: 0.8482
# Epoch 54/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4141 - accuracy: 0.8549
# Epoch 55/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4120 - accuracy: 0.8549
# Epoch 56/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4103 - accuracy: 0.8571
# Epoch 57/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4069 - accuracy: 0.8616
# Epoch 58/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4061 - accuracy: 0.8571
# Epoch 59/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4048 - accuracy: 0.8638
# Epoch 60/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4032 - accuracy: 0.8616
# Epoch 61/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4037 - accuracy: 0.8594
# Epoch 62/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.4004 - accuracy: 0.8549
# Epoch 63/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3984 - accuracy: 0.8616
# Epoch 64/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3973 - accuracy: 0.8661
# Epoch 65/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3952 - accuracy: 0.8683
# Epoch 66/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3947 - accuracy: 0.8661
# Epoch 67/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3919 - accuracy: 0.8638
# Epoch 68/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3900 - accuracy: 0.8683
# Epoch 69/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3884 - accuracy: 0.8705
# Epoch 70/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3883 - accuracy: 0.8705
# Epoch 71/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3859 - accuracy: 0.8683
# Epoch 72/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3836 - accuracy: 0.8705
# Epoch 73/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3819 - accuracy: 0.8705
# Epoch 74/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3844 - accuracy: 0.8661
# Epoch 75/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3784 - accuracy: 0.8683
# Epoch 76/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3788 - accuracy: 0.8705
# Epoch 77/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3765 - accuracy: 0.8661
# Epoch 78/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3738 - accuracy: 0.8705
# Epoch 79/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3724 - accuracy: 0.8772
# Epoch 80/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3699 - accuracy: 0.8728
# Epoch 81/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3684 - accuracy: 0.8705
# Epoch 82/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3658 - accuracy: 0.8772
# Epoch 83/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3659 - accuracy: 0.8750
# Epoch 84/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3647 - accuracy: 0.8795
# Epoch 85/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3635 - accuracy: 0.8772
# Epoch 86/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3614 - accuracy: 0.8817
# Epoch 87/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3605 - accuracy: 0.8750
# Epoch 88/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3599 - accuracy: 0.8705
# Epoch 89/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3559 - accuracy: 0.8795
# Epoch 90/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3538 - accuracy: 0.8795
# Epoch 91/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3565 - accuracy: 0.8728
# Epoch 92/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3538 - accuracy: 0.8839
# Epoch 93/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3508 - accuracy: 0.8817
# Epoch 94/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3487 - accuracy: 0.8839
# Epoch 95/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3470 - accuracy: 0.8862
# Epoch 96/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3453 - accuracy: 0.8839
# Epoch 97/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3445 - accuracy: 0.8862
# Epoch 98/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3436 - accuracy: 0.8839
# Epoch 99/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3413 - accuracy: 0.8906
# Epoch 100/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3381 - accuracy: 0.8906

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 5/5 - 0s - loss: 0.5734 - accuracy: 0.7533 - 160ms/epoch - 32ms/step
# Loss: 0.5733734369277954, Accuracy: 0.753333330154419

# %%
# Export our model to HDF5 file
nn.save('/content/drive/MyDrive/project4/Output/ModelTest.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Creating Logistic Regression Model
lr_model = LogisticRegression()

# %%
# Train the model
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr_model.predict(X_test)

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.33      0.45        46
#            1       0.76      0.95      0.85       104
#
#     accuracy                           0.76       150
#    macro avg       0.76      0.64      0.65       150
# weighted avg       0.76      0.76      0.73       150

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.76

# %%
rf_model = RandomForestClassifier(n_estimators=200, random_state=78)
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
predictions = rf_model.predict(X_test_scaled)

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0           20           26
# Actual 1            5           99
# Accuracy Score : 0.7933333333333333
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.43      0.56        46
#            1       0.79      0.95      0.86       104
#
#     accuracy                           0.79       150
#    macro avg       0.80      0.69      0.71       150
# weighted avg       0.79      0.79      0.77       150

# %%
# Random Forests in sklearn will automatically calculate feature importance
importances = rf_model.feature_importances_
# We can sort the features by their importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.2988641550375353, 'Credit_History'),
#  (0.2562019308628828, 'Total_Income'),
#  (0.22000216007302228, 'LoanAmount'),
#  (0.062208795183772064, 'Dependents'),
#  (0.03690454880063977, 'Loan_Amount_Term'),
#  (0.026725596014185435, 'Education'),
#  (0.026217455280960516, 'Married'),
#  (0.024705608180768432, 'Self_Employed'),
#  (0.017965747891886083, 'Property_Area_Rural'),
#  (0.01753713484267622, 'Property_Area_Semiurban'),
#  (0.012666867831671105, 'Property_Area_Urban')]

# %%
# Visualize the features by importance
importances_df = pd.DataFrame(sorted(zip(rf_model.feature_importances_, X.columns), reverse=True))
importances_df.set_index(importances_df[1], inplace=True)
importances_df.drop(columns=1, inplace=True)
importances_df.rename(columns={0: 'Feature Importances'}, inplace=True)
importances_sorted = importances_df.sort_values(by='Feature Importances')
importances_sorted.plot(kind='barh', color='lightgreen', title= 'Features Importances', legend=False)
# Out:
# <Axes: title={'center': 'Features Importances'}, ylabel='1'>
